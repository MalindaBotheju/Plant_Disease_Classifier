# %% [markdown]
# <a href="https://colab.research.google.com/github/MalindaBotheju/Plant_Disease_Classifier/blob/main/Plant_Disease_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/Plant_Disease_Classifier
# !ls -la
# Out:
# [Errno 2] No such file or directory: '/content/Plant_Disease_Classifier'
# /content
# total 16
# drwxr-xr-x 1 root root 4096 Dec  9 14:41 .
# drwxr-xr-x 1 root root 4096 Feb  8 13:47 ..
# drwxr-xr-x 4 root root 4096 Dec  9 14:41 .config
# drwxr-xr-x 1 root root 4096 Dec  9 14:42 sample_data

# %%
# %cd /content/Plant_Disease_Classifier
# !git status
# !git pull
# Out:
# [Errno 2] No such file or directory: '/content/Plant_Disease_Classifier'
# /content
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %cd /content/Plant_Disease_Classifier
# !git add .
# !git commit -m "Add notebook and project structure"
# !git push
# Out:
# [Errno 2] No such file or directory: '/content/Plant_Disease_Classifier'
# /content
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# **Check GPU**

# %%
import torch
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Torch: 2.9.0+cu126
# CUDA available: True
# GPU: Tesla T4

# %% [markdown]
# **install/import basics**

# %%
# !pip -q install torch torchvision tqdm matplotlib scikit-learn

import os, json, time
from datetime import datetime

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# **create “modern outputs” run folder**

# %%
RUN_NAME = "run_001"
OUT_DIR = f"outputs/{RUN_NAME}"
os.makedirs(OUT_DIR, exist_ok=True)

# Save a small run config file (helps later)
config = {
    "run_name": RUN_NAME,
    "created_at": datetime.now().isoformat(),
}
with open(os.path.join(OUT_DIR, "config.json"), "w") as f:
    json.dump(config, f, indent=2)

print("Output folder ready:", OUT_DIR)
# Out:
# Output folder ready: outputs/run_001

# %% [markdown]
# **device**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')
